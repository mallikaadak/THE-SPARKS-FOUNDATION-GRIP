# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns

# To ignore the warnings 
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv("D:\MALLIKA\owid-covid-data.csv")
df
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1           AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2           AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3           AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4           AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 106558      ZWE    Africa     Zimbabwe  7/28/2021     103567.0     1856.0
# 106559      ZWE    Africa     Zimbabwe  7/29/2021     105656.0     2089.0
# 106560      ZWE    Africa     Zimbabwe  7/30/2021     107490.0     1834.0
# 106561      ZWE    Africa     Zimbabwe  7/31/2021     108860.0     1370.0
# 106562      ZWE    Africa     Zimbabwe   8/1/2021     109546.0      686.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
#Take a look at dataset
df.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# 5      AFG      Asia  Afghanistan  2/29/2020          1.0        0.0
# 6      AFG      Asia  Afghanistan   3/1/2020          1.0        0.0
# 7      AFG      Asia  Afghanistan   3/2/2020          1.0        0.0
# 8      AFG      Asia  Afghanistan   3/3/2020          2.0        1.0
# 9      AFG      Asia  Afghanistan   3/4/2020          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
#Take a look at dataset
df.tail(10)
# Out:
#        iso_code continent  location       date  total_cases  new_cases  \
# 106553      ZWE    Africa  Zimbabwe  7/23/2021      95686.0     2265.0
# 106554      ZWE    Africa  Zimbabwe  7/24/2021      97277.0     1591.0
# 106555      ZWE    Africa  Zimbabwe  7/25/2021      97894.0      617.0
# 106556      ZWE    Africa  Zimbabwe  7/26/2021      99944.0     2050.0
# 106557      ZWE    Africa  Zimbabwe  7/27/2021     101711.0     1767.0
# 106558      ZWE    Africa  Zimbabwe  7/28/2021     103567.0     1856.0
# 106559      ZWE    Africa  Zimbabwe  7/29/2021     105656.0     2089.0
# 106560      ZWE    Africa  Zimbabwe  7/30/2021     107490.0     1834.0
# 106561      ZWE    Africa  Zimbabwe  7/31/2021     108860.0     1370.0
# 106562      ZWE    Africa  Zimbabwe   8/1/2021     109546.0      686.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 106553            2074.000        2961.0        91.0               63.000
# ...

# %%
df.shape
# Out:
# (106563, 60)

# %%
#Summarize the data
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.022120e+05  102209.000000       101199.000000  9.186300e+04
# mean   1.182084e+06    6147.782964         6155.983747  3.128293e+04
# std    8.022777e+06   38005.570356        37641.795398  1.867392e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.485000e+03       2.000000            7.857000  5.900000e+01
# 50%    1.548050e+04      78.000000           96.286000  4.540000e+02
# 75%    1.645838e+05     846.000000          893.714000  4.350000e+03
# max    1.983378e+08  905993.000000       826368.143000  4.224466e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  92018.000000        101199.000000            101670.000000
# mean     145.528190           131.520239             14612.467399
# std      795.769281           740.801484             26185.169284
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106563 entries, 0 to 106562
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               106563 non-null  object
#  1   continent                              101615 non-null  object
#  2   location                               106563 non-null  object
#  3   date                                   106563 non-null  object
#  4   total_cases                            102212 non-null  float64
#  5   new_cases                              102209 non-null  float64
#  6   new_cases_smoothed                     101199 non-null  float64
#  7   total_deaths                           91863 non-null   float64
#  8   new_deaths                             92018 non-null   float64
#  9   new_deaths_smoothed                    101199 non-null  float64
# ...

# %%
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 60)

# %%
df.count() #Used to count the number of rows
# Out:
# iso_code                                 106563
# continent                                101615
# location                                 106563
# date                                     106563
# total_cases                              102212
# new_cases                                102209
# new_cases_smoothed                       101199
# total_deaths                              91863
# new_deaths                                92018
# new_deaths_smoothed                      101199
# total_cases_per_million                  101670
# new_cases_per_million                    101667
# new_cases_smoothed_per_million           100662
# total_deaths_per_million                  91334
# new_deaths_per_million                    91489
# new_deaths_smoothed_per_million          100662
# reproduction_rate                         85927
# icu_patients                              11030
# icu_patients_per_million                  11030
# hosp_patients                             13316
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                      0
# continent                                  4948
# location                                      0
# date                                          0
# total_cases                                4351
# new_cases                                  4354
# new_cases_smoothed                         5364
# total_deaths                              14700
# new_deaths                                14545
# new_deaths_smoothed                        5364
# total_cases_per_million                    4893
# new_cases_per_million                      4896
# new_cases_smoothed_per_million             5901
# total_deaths_per_million                  15229
# new_deaths_per_million                    15074
# new_deaths_smoothed_per_million            5901
# reproduction_rate                         20636
# icu_patients                              95533
# icu_patients_per_million                  95533
# hosp_patients                             93247
# ...

# %%
df1 = df[["date", "total_cases", "new_cases", "total_deaths", "new_tests", "total_tests"]]
df1.head()
# Out:
#         date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2/24/2020          1.0        1.0           NaN        NaN          NaN
# 1  2/25/2020          1.0        0.0           NaN        NaN          NaN
# 2  2/26/2020          1.0        0.0           NaN        NaN          NaN
# 3  2/27/2020          1.0        0.0           NaN        NaN          NaN
# 4  2/28/2020          1.0        0.0           NaN        NaN          NaN

# %%
df1.date = pd.to_datetime(df.date)

df1.set_index('date', inplace = True)

# %%
df1.head()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-02-24          1.0        1.0           NaN        NaN          NaN
# 2020-02-25          1.0        0.0           NaN        NaN          NaN
# 2020-02-26          1.0        0.0           NaN        NaN          NaN
# 2020-02-27          1.0        0.0           NaN        NaN          NaN
# 2020-02-28          1.0        0.0           NaN        NaN          NaN

# %%
df1.tail()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2021-07-28     103567.0     1856.0        3340.0        NaN          NaN
# 2021-07-29     105656.0     2089.0        3421.0        NaN          NaN
# 2021-07-30     107490.0     1834.0        3490.0        NaN          NaN
# 2021-07-31     108860.0     1370.0        3532.0        NaN          NaN
# 2021-08-01     109546.0      686.0        3583.0        NaN          NaN

# %%
df1.corr()
# Out:
#               total_cases  new_cases  total_deaths  new_tests  total_tests
# total_cases      1.000000   0.831258      0.986312   0.777969     0.957532
# new_cases        0.831258   1.000000      0.836870   0.751213     0.587962
# total_deaths     0.986312   0.836870      1.000000   0.713205     0.872426
# new_tests        0.777969   0.751213      0.713205   1.000000     0.827517
# total_tests      0.957532   0.587962      0.872426   0.827517     1.000000

# %%
# plotting the heatmap of correlation matrix using seaborn
fig=plt.figure(figsize=(8,6))
sns.heatmap(df1.corr(), annot=True)
plt.title('Correlation Between Variables',fontsize='15')
plt.show()

# %%
#histogram for Visualizing
df1.hist(bins = 50,figsize = (15,11));

# %%
df1.plot(figsize = (15 , 8), linewidth = 5)
plt.xlabel('Month')
plt.show()

# %%
# Analyzing cases worldwide 
dataset = df[df['date']=='8/1/2021']
dataset = df[~df['location'].isin(['World','International'])]
dataset.head(10)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# 5      AFG      Asia  Afghanistan  2/29/2020          1.0        0.0
# 6      AFG      Asia  Afghanistan   3/1/2020          1.0        0.0
# 7      AFG      Asia  Afghanistan   3/2/2020          1.0        0.0
# 8      AFG      Asia  Afghanistan   3/3/2020          2.0        1.0
# 9      AFG      Asia  Afghanistan   3/4/2020          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
# looking at different locations
df["location"].value_counts()
# Out:
# Peru                               579
# Mexico                             579
# Argentina                          579
# Thailand                           576
# Taiwan                             564
#                                   ...
# Tuvalu                              50
# Pitcairn                            43
# Niue                                16
# Turkmenistan                         1
# Bonaire Sint Eustatius and Saba      1
# Name: location, Length: 231, dtype: int64

# %%
df["location"].value_counts()[1:25]
# Out:
# Mexico            579
# Argentina         579
# Thailand          576
# Taiwan            564
# South Korea       559
# China             558
# Japan             558
# World             558
# North America     558
# Asia              558
# United States     558
# Hong Kong         557
# Europe            557
# Vietnam           557
# Singapore         557
# European Union    557
# Germany           556
# France            556
# Malaysia          555
# Oceania           555
# Nepal             555
# Australia         554
# Canada            554
# Sri Lanka         553
# Name: location, dtype: int64

# %%
df['location'].value_counts().head(25).plot(kind='pie',autopct='%1.1f%%',figsize=(25,25),startangle=180,fontsize='30')
plt.title("COVID-19 CASES IN VARIOUS LOCATION",fontsize=50)
plt.show()

# %%
# covid cases in india
india=df[df["location"]=="India"]
india.head()
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 44046      IND      Asia    India  1/30/2020          1.0        1.0
# 44047      IND      Asia    India  1/31/2020          1.0        0.0
# 44048      IND      Asia    India   2/1/2020          1.0        0.0
# 44049      IND      Asia    India   2/2/2020          2.0        1.0
# 44050      IND      Asia    India   2/3/2020          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 44046                 NaN           NaN         NaN                  NaN  ...
# 44047                 NaN           NaN         NaN                  NaN  ...
# 44048                 NaN           NaN         NaN                  NaN  ...
# 44049                 NaN           NaN         NaN                  NaN  ...
# 44050                 NaN           NaN         NaN                  NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
#Data Visualization
sns.set(rc={"figure.figsize":(15,10)})
sns.lineplot(x="date",y="total_cases",data=india)
plt.show()

# %%
plt.subplots(figsize=(15,8))
sns.barplot(india['date'].value_counts().index,india['total_cases'].value_counts().values,palette='rocket')
plt.title('Top Countries Affected',fontsize='15')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-187ff94b0805> in <module>
#       1 plt.subplots(figsize=(15,8))
# ----> 2 sns.barplot(india['date'].value_counts().index,india['total_cases'].value_counts().values,palette='rocket')
#       3 plt.title('Top Countries Affected',fontsize='15')
#       4 plt.xlabel('Countries')
#       5 plt.ylabel('Count')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# ...

# %%
# plot on bar plot
plt.subplots(figsize=(10,6))
sns.barplot(x="date",y="total_cases",data=india,palette='rocket')
plt.show()

# %%
pd.crosstab(df1.total_cases, df1.total_tests).plot(kind='area',figsize=(15,8))
plt.title('Terrorist Activities By Region In Each Year',fontsize='15')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-cc389241661c> in <module>
# ----> 1 pd.crosstab(df1.total_cases, df1.total_tests).plot(kind='area',figsize=(15,8))
#       2 plt.title('Terrorist Activities By Region In Each Year',fontsize='15')
#       3 plt.xlabel('Year')
#       4 plt.ylabel('Number of Attacks')
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     606         kwargs = {"aggfunc": aggfunc}
#     607
# --> 608     table = df.pivot_table(
#     609         ["__dummy__"],
#     610         index=unique_rownames,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
# ...

# %%
last_day_cases=df[(df["date"]=="8/1/2021")]
last_day_cases

# %%
# sorting date w.r.t to total cases

max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country

# %%
# sorting date w.r.t to total cases

max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country

# %%
# top 5 countries with maximum case
max_cases_country[1:6]

# %%
# plot on bar plot
plt.subplots(figsize=(10,6))
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],palette='rocket')
plt.show()

# %%
max_cases_country['location'].value_counts().head(25).plot(kind='pie',autopct='%1.1f%%',figsize=(25,25),startangle=180,fontsize='30')
plt.title("COVID-19 CASES IN VARIOUS LOCATION",fontsize=50)
plt.show()

# %%
df['total_cases'].value_counts().head(25).plot(kind='pie',autopct='%1.1f%%',figsize=(25,25),startangle=180,fontsize='30')
plt.title("COVID-19 CASES IN VARIOUS LOCATION",fontsize=50)
plt.legend()
plt.show()

# %%
max_death=last_day_cases.sort_values(by="total_deaths",ascending=False)
max_death

# %%
max_death['location'].value_counts().head(25).plot(kind='pie',autopct='%1.1f%%',figsize=(25,25),startangle=180,fontsize='30')
plt.title("COVID-19 CASES IN VARIOUS LOCATION",fontsize=50)
plt.show()

# %%
df1.total_cases.plot(figsize = (12 , 8), linewidth = 5, fontsize = 15,color ='r')

plt.xlabel('Month', fontsize = 15)

# %%
# plot on bar plot
plt.subplots(figsize=(10,6))
sns.barplot(x="Month",y="total_cases",data=df1[1:20],palette='rocket')
plt.show()

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)

plt.xlabel('Month', fontsize = 20)
